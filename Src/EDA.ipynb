# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\Portfolio\Src\Data\Big_Japan_vs_China_Technology.csv")
df.head(10)
# Out:
#   Country  Year      Tech Sector  Market Share (%)  R&D Investment (in USD)  \
# 0   China  2001         Software         22.279014             8.377208e+10
# 1   Japan  2011    Semiconductor         31.899013             3.551134e+10
# 2   Japan  2009         Robotics         33.574466             8.480948e+10
# 3   Japan  2019  Cloud Computing         24.904248             2.267821e+10
# 4   China  2002         Robotics         46.975827             3.453655e+10
# 5   China  2022    Semiconductor         12.741990             4.029329e+10
# 6   China  2022  Cloud Computing         20.476168             4.823453e+10
# 7   China  2006         Robotics         22.585881             2.177051e+10
# 8   China  2011               AI         12.751686             1.179936e+10
# 9   Japan  2002    Biotechnology         37.217951             9.792535e+09
#
#    Number of Patents Filed (Annual)  Number of Tech Companies  \
# 0                              1415                       878
# 1                              7899                       364
# 2                              3749                       425
# 3                              3841                        62
# 4                              1704                       458
# 5                               186                       792
# 6                              4313                      1738
# 7                              8170                      1437
# 8                              7535                      1879
# 9                              3198                       601
#
#    Tech Exports (in USD)  Number of Startups  \
# 0           3.503155e+10                 166
# 1           3.714209e+10                 217
# 2           1.570406e+11                 451
# 3           1.031284e+11                 264
# 4           1.112056e+11                 463
# 5           1.686877e+09                 247
# 6           1.011623e+11                 123
# 7           8.788322e+10                 131
# 8           1.308955e+11                 269
# 9           1.601066e+10                  46
#
#    Venture Capital Funding (in USD)  Global Innovation Ranking  \
# 0                      4.502694e+10                         11
# 1                      1.147381e+10                         14
# 2                      5.498885e+09                         14
# 3                      2.186278e+10                         10
# 4                      4.098282e+10                         10
# 5                      3.380235e+10                          6
# 6                      3.323102e+10                         17
# 7                      1.833492e+10                         19
# 8                      2.719328e+09                         19
# 9                      2.219210e+10                         14
#
#    Internet Penetration (%)  5G Network Coverage (%)  \
# 0                 57.088673                82.240272
# 1                 78.172090                48.552982
# 2                 55.810668                66.495286
# 3                 78.553714                28.807251
# 4                 70.427548                38.746268
# 5                 94.040043                21.801071
# 6                 41.655595                88.214560
# 7                 60.013180                65.573974
# 8                 86.144044                17.922373
# 9                 66.944509                45.175813
#
#    University Research Collaborations Top Tech Products Exported  \
# 0                                  50                     Robots
# 1                                 134               5G Equipment
# 2                                  58             Semiconductors
# 3                                 150                     Robots
# 4                                  74                   AI Chips
# 5                                  24                     Robots
# 6                                  17               5G Equipment
# 7                                 112                   AI Chips
# 8                                  95                     Robots
# 9                                 132              Cloud Servers
#
#    Number of Tech Workers
# 0                  621221
# 1                  431928
# 2                   55776
# 3                  267852
# 4                  654162
# 5                  437676
# 6                  225028
# 7                  146593
# 8                  914680
# 9                  382884

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             1000 non-null   object
#  1   Year                                1000 non-null   int64
#  2   Tech Sector                         1000 non-null   object
#  3   Market Share (%)                    1000 non-null   float64
#  4   R&D Investment (in USD)             1000 non-null   float64
#  5   Number of Patents Filed (Annual)    1000 non-null   int64
#  6   Number of Tech Companies            1000 non-null   int64
#  7   Tech Exports (in USD)               1000 non-null   float64
#  8   Number of Startups                  1000 non-null   int64
#  9   Venture Capital Funding (in USD)    1000 non-null   float64
#  10  Global Innovation Ranking           1000 non-null   int64
#  11  Internet Penetration (%)            1000 non-null   float64
#  12  5G Network Coverage (%)             1000 non-null   float64
#  13  University Research Collaborations  1000 non-null   int64
#  14  Top Tech Products Exported          1000 non-null   object
#  15  Number of Tech Workers              1000 non-null   int64
# dtypes: float64(6), int64(7), object(3)
# memory usage: 125.1+ KB

# %%
df.describe()
# Out:
#               Year  Market Share (%)  R&D Investment (in USD)  \
# count  1000.000000       1000.000000             1.000000e+03
# mean   2011.497000         27.439221             5.034591e+10
# std       6.991486         12.808159             2.829704e+10
# min    2000.000000          5.033959             1.056575e+09
# 25%    2005.000000         16.333641             2.558291e+10
# 50%    2012.000000         27.111042             5.010075e+10
# 75%    2017.250000         38.480568             7.492896e+10
# max    2023.000000         49.955344             9.997537e+10
#
#        Number of Patents Filed (Annual)  Number of Tech Companies  \
# count                       1000.000000               1000.000000
# mean                        5094.686000               1011.133000
# std                         2846.164392                563.223321
# min                          119.000000                 52.000000
# 25%                         2789.500000                503.000000
# 50%                         5021.000000                998.500000
# 75%                         7569.500000               1494.250000
# max                         9989.000000               1999.000000
#
#        Tech Exports (in USD)  Number of Startups  \
# count           1.000000e+03         1000.000000
# mean            9.905279e+10          257.524000
# std             5.921177e+10          143.525939
# min             1.072723e+09           11.000000
# 25%             4.605266e+10          131.000000
# 50%             9.671071e+10          257.500000
# 75%             1.520491e+11          382.250000
# max             1.997280e+11          499.000000
#
#        Venture Capital Funding (in USD)  Global Innovation Ranking  \
# count                      1.000000e+03                1000.000000
# mean                       2.467234e+10                  10.003000
# std                        1.469330e+10                   5.533318
# min                        3.681449e+07                   1.000000
# 25%                        1.195372e+10                   5.000000
# 50%                        2.453826e+10                  10.000000
# 75%                        3.711508e+10                  15.000000
# max                        4.991708e+10                  19.000000
#
#        Internet Penetration (%)  5G Network Coverage (%)  \
# count               1000.000000              1000.000000
# mean                  69.739498                49.970784
# std                   17.071675                23.012153
# min                   40.079130                10.043427
# 25%                   54.879624                29.796081
# 50%                   70.257998                51.150191
# 75%                   84.408627                69.795189
# max                   99.935228                89.904580
#
#        University Research Collaborations  Number of Tech Workers
# count                         1000.000000             1000.000000
# mean                            99.084000           496483.411000
# std                             55.374319           290405.281594
# min                              1.000000             2422.000000
# 25%                             53.000000           248962.500000
# 50%                            100.000000           505236.000000
# 75%                            147.000000           737879.250000
# max                            199.000000           996999.000000

# %%
total_exports_japan = df[df['Country'] == 'Japan']['Tech Exports (in USD)'].sum()
total_exports_china = df[df['Country'] == 'China']['Tech Exports (in USD)'].sum()

# %%
print(total_exports_japan)
print(total_exports_china)
# Out:
# 49903882818907.91
# 49148911623777.375

# %%
countries = ['Japan', 'China']
total_exports = [total_exports_japan, total_exports_china]
# Create a bar plot
plt.bar(countries, total_exports, color=['blue', 'red'])
# Adding title and labels
plt.title('Comparison of Total Tech Exports')
plt.xlabel('Country')
plt.ylabel('Total Tech Exports (in USD)')
plt.show()

# %%
# Dùng data của từng nước để xác định outliers
# Tính correlation để xác định các columns liên quan đến nhau
# Compare Density of each Test Sector by Market Share
# Compare R and D Investment 
# Compare Start up company between China and Japan 
# Which country is more innovative in terms of patent filings and technological advancements?
# How does the entrepreneurial landscape differ between the two countries?
# Which country has a more developed technology sector in terms of exports and startups?
# What are the factors driving the differences in technological development between China and Japan?

# %% [markdown]
# From correlation matrix we can easily see the relationship between columns:
# - Positive Correlation:
# + + R&D Investment with Number of Patents Filed
# + + Number of Tech Companies with Tech Exports
# + + Market Share and R&D Investment
# + + NUmber of Tech Companies and Number of Patents filed
# - Negative Correlation:
# + + Global Innovation Ranking and Internet Penetration
# + + Global Innovation Ranking and 5G Network Coverage
# + + Venture Capital Funding with others attributes

# %%
numerical_cols = df.select_dtypes(include=['number']).columns
numerical_cols.drop('Year')
# Out:
# Country                                object
# Year                                    int64
# Tech Sector                            object
# Market Share (%)                      float64
# R&D Investment (in USD)               float64
# Number of Patents Filed (Annual)        int64
# Number of Tech Companies                int64
# Tech Exports (in USD)                 float64
# Number of Startups                      int64
# Venture Capital Funding (in USD)      float64
# Global Innovation Ranking               int64
# Internet Penetration (%)              float64
# 5G Network Coverage (%)               float64
# University Research Collaborations      int64
# Top Tech Products Exported             object
# Number of Tech Workers                  int64
# dtype: object

# %%
# Select only numerical columns for correlation calculation
numerical_cols = df.select_dtypes(include=['number']).columns

# Calculate correlation matrix
correlation_matrix = df[numerical_cols].corr()

# Plotting the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Indicators')
plt.show()

# %% [markdown]
# - R & D Investment refers to the funds of that a company or gorvement that spends on researching and developing new products, technologies, or services. In this datasets, R&D Investment reflect the amount of money of China and Japan's goverment have invested(2001-2022)
# - From the plot, we can see that:
# + 2000 - 2005:
# + Both goverment have spent money stable but Japan spent more on this phase
# + 2005 - 2010:
# + China had a strong investment during this period, with investment capital increasing strongly compared to Japan and at times even higher than Japan.
# + 2010 - 2022:
# + From 2015 onward, Japan investment becomes more comparable or even slightly higher than China
# - Conclusion:
# --> Japan have invested in this field more stable and more money than China, this can prove by the Confidence Interval in the plot(the CI of China is wider than Japan)

# %%
sns.lineplot(data=df, x=df["Year"], y=df['R&D Investment (in USD)'],hue=df['Country'],marker='o')
plt.title('R&D Investment in Japan Over the Years')
plt.show()
# Out:
# d:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='R&D Investment (in USD)', hue='Country', kde=True, palette='Set2')
plt.title('Distribution of R&D Investment (in USD) (China vs Japan)')
plt.xlabel('R&D Investment (in USD)')
plt.show()
# Out:
# d:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# The correlation show that R&D Investment has strong relationship with Number of Patents Filed. The

# %%
# R and D Investment and Number of Patents Filed
# Scatter plot with regression line
japan_data = df[df['Country'] == 'Japan']
total_rd_investment_japan = japan_data['R&D Investment (in USD)'].sum()
china_data = df[df['Country'] == 'China']
total_rd_investment_china = china_data['R&D Investment (in USD)'].sum()
total_patents_japan = df[df['Country'] == 'Japan']['Number of Patents Filed (Annual)'].sum()
total_patents_china = df[df['Country'] == 'China']['Number of Patents Filed (Annual)'].sum()

# %%
sns.barplot(data=df,x=df['Tech Sector'],y=df['Market Share (%)'],hue=df['Country'])
plt.title('Density of Tech Sector in Japan and China over the years')
plt.xticks(rotation = 45)
plt.show()
